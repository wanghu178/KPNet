# %%
import torch.nn as nn
import torch

# %%
path = r"D:\experiment\KUNet2\model\brain\brain_three_XY_msl_lr_37\latest_G.pth"
content = torch.load(path)

# %%
print(content.keys())
# Out:
# odict_keys(['conv_first.weight', 'conv_first.bias', 'down_conv1.weight', 'down_conv1.bias', 'down_conv2.weight', 'down_conv2.bias', 'down_fea1.weight', 'down_fea1.bias', 'recon_trunk.split_hl.h2l.weight', 'recon_trunk.split_hl.h2h.weight', 'recon_trunk.conv_h.0.conv.weight', 'recon_trunk.conv_h.0.conv.bias', 'recon_trunk.conv_h.1.conv.weight', 'recon_trunk.conv_h.1.conv.bias', 'recon_trunk.conv_l.0.conv.weight', 'recon_trunk.conv_l.0.conv.bias', 'recon_trunk.conv_l.1.conv.weight', 'recon_trunk.conv_l.1.conv.bias', 'recon_trunk.up_sampel.0.weight', 'recon_trunk.up_sampel.0.bias', 'recon_trunk.refine.0.conv.weight', 'recon_trunk.refine.0.conv.bias', 'recon_trunk.refine.1.conv.weight', 'recon_trunk.refine.1.conv.bias', 'up_conv1.0.weight', 'up_conv1.0.bias', 'up_conv2.0.weight', 'up_conv2.0.bias', 'up_KIB2.0.weight', 'up_KIB2.0.bias', 'conv_last.weight', 'conv_last.bias', 'brain.w1', 'brain.w2', 'brain.w3', 'brain.conv1.0.conv.weight', 'brain.conv1.0.conv.bias', 'brain.conv2.0.conv.weig
# ...

# %%
print(content['brain.w1'])
# Out:
# tensor([0.1483])

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
def read_imgdata(path, ratio=255.0):
    return cv2.imread(path, cv2.IMREAD_UNCHANGED) / ratio

# %%
path1 = r"E:\NTIRE_single\train\hdr\0001_gt_s001.png"
alignration_path = r"E:\NTIRE_single\train\alignratio\0001_alignratio.npy"

# %%
alignratio = np.load(alignration_path)
img = read_imgdata(path1)
img = img[:, :, [2, 1, 0]]
plt.imshow(img)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
